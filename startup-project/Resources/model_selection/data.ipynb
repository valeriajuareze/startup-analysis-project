# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
startup_df = pd.read_csv("Resources/startup data.csv")

# %%
startup_df.drop(columns=["closed_at", "Unnamed: 6", "status", "id", "object_id", "name", "state_code.1","city", "state_code", "category_code", "Unnamed: 0", "latitude", "longitude", "zip_code"], axis=1, inplace=True)

# %%
startup_df
# Out:
#      labels founded_at first_funding_at last_funding_at  \
# 0         1   1/1/2007         4/1/2009        1/1/2010
# 1         1   1/1/2000        2/14/2005      12/28/2009
# 2         1  3/18/2009        3/30/2010       3/30/2010
# 3         1   1/1/2002        2/17/2005       4/25/2007
# 4         0   8/1/2010         8/1/2010        4/1/2012
# ..      ...        ...              ...             ...
# 918       1   1/1/2009         7/9/2009        7/9/2009
# 919       0   1/1/1998         4/1/2005       3/23/2007
# 920       0   1/1/1999        6/29/2007       6/29/2007
# 921       1   1/1/2009        10/5/2009       11/1/2011
# 922       1   1/1/2003        2/13/2006       2/13/2006
#
#      age_first_funding_year  age_last_funding_year  age_first_milestone_year  \
# 0                    2.2493                 3.0027                    4.6685
# 1                    5.1260                 9.9973                    7.0055
# ...

# %%
start_corr = startup_df.corr()
start_corr["age_first_milestone_year"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
start_try = startup_df.dropna()
start_try.count()
# Out:
# labels                                    771
# age_first_funding_year                    771
# age_last_funding_year                     771
# age_first_milestone_year                  771
# age_last_milestone_year                   771
# relationships                             771
# funding_rounds                            771
# funding_total_usd                         771
# milestones                                771
# is_CA                                     771
# is_NY                                     771
# is_MA                                     771
# is_TX                                     771
# is_otherstate                             771
# is_software                               771
# is_web                                    771
# is_mobile                                 771
# is_enterprise                             771
# is_advertising                            771
# is_gamesvideo                             771
# ...

# %%
startup_df.age_last_milestone_year.isnull().sum()
# Out:
# 152

# %%
startup_df[startup_df.age_first_milestone_year.isnull()]
# Out:
#      labels founded_at first_funding_at last_funding_at  \
# 12        0   1/1/2004       11/25/2008      11/25/2008
# 15        0   1/1/1999         8/9/2005        8/9/2005
# 24        0   5/1/2007         8/1/2007        9/1/2007
# 32        0  10/1/2006         8/1/2006       10/7/2008
# 34        0   6/1/2009         7/1/2009        7/1/2009
# ..      ...        ...              ...             ...
# 885       0   1/1/2005        8/27/2008       8/27/2008
# 903       1   1/1/2002        10/3/2005       10/3/2005
# 904       0   1/1/2003        4/12/2007       4/12/2007
# 906       1   1/1/2000        4/20/2005       8/14/2008
# 912       1  4/22/2005       11/29/2006       11/7/2008
#
#      age_first_funding_year  age_last_funding_year  age_first_milestone_year  \
# 12                   4.9041                 4.9041                       NaN
# 15                   6.6082                 6.6082                       NaN
# ...

# %%
startup_df.age_first_milestone_year.value_counts()
# Out:
#  0.0000    45
#  4.0027    26
#  2.0000    16
#  3.0027    15
#  1.0000    15
#            ..
# -0.4192     1
#  6.4247     1
#  5.3151     1
#  5.6959     1
#  0.7589     1
# Name: age_first_milestone_year, Length: 471, dtype: int64

# %%
startup_df[startup_df.age_first_milestone_year.isnull()].labels.value_counts()
# Out:
# 0    105
# 1     47
# Name: labels, dtype: int64

# %%
startup_df["reached_milestone"] = startup_df.age_first_milestone_year.map(lambda x: 0 if pd.isnull(x) else 1)

# %%
startup_df.head()
# Out:
#    labels founded_at first_funding_at last_funding_at  age_first_funding_year  \
# 0       1   1/1/2007         4/1/2009        1/1/2010                  2.2493
# 1       1   1/1/2000        2/14/2005      12/28/2009                  5.1260
# 2       1  3/18/2009        3/30/2010       3/30/2010                  1.0329
# 3       1   1/1/2002        2/17/2005       4/25/2007                  3.1315
# 4       0   8/1/2010         8/1/2010        4/1/2012                  0.0000
#
#    age_last_funding_year  age_first_milestone_year  age_last_milestone_year  \
# 0                 3.0027                    4.6685                   6.7041
# 1                 9.9973                    7.0055                   7.0055
# 2                 1.0329                    1.4575                   2.2055
# 3                 5.3151                    6.0027                   6.0027
# 4                 1.6685                    0.0384                   0.0384
#
# ...

# %%
# startup_df.dropna(inplace=True)

# %%
startup_df.columns
# Out:
# Index(['labels', 'founded_at', 'first_funding_at', 'last_funding_at',
#        'age_first_funding_year', 'age_last_funding_year',
#        'age_first_milestone_year', 'age_last_milestone_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'is_software', 'is_web', 'is_mobile',
#        'is_enterprise', 'is_advertising', 'is_gamesvideo', 'is_ecommerce',
#        'is_biotech', 'is_consulting', 'is_othercategory', 'has_VC',
#        'has_angel', 'has_roundA', 'has_roundB', 'has_roundC', 'has_roundD',
#        'avg_participants', 'is_top500', 'reached_milestone'],
#       dtype='object')

# %%
startup_df.founded_at = pd.to_datetime(startup_df.founded_at)
startup_df.first_funding_at = pd.to_datetime(startup_df.first_funding_at)
startup_df.last_funding_at = pd.to_datetime(startup_df.last_funding_at)

# %%
startup_df.founded_at.map(lambda x: x.year)
# Out:
# 0      2007
# 1      2000
# 2      2009
# 3      2002
# 4      2010
#        ...
# 918    2009
# 919    1998
# 920    1999
# 921    2009
# 922    2003
# Name: founded_at, Length: 923, dtype: int64

# %%
startup_df["founded_first_funding__days_difference"] = startup_df.first_funding_at - startup_df.founded_at
startup_df["first_last_funding_days_difference"] = startup_df.last_funding_at - startup_df.first_funding_at

# %%
startup_df.founded_first_funding__days_difference = startup_df.founded_first_funding__days_difference.astype('timedelta64[D]').astype(int)
startup_df.first_last_funding_days_difference = startup_df.first_last_funding_days_difference.astype('timedelta64[D]').astype(int)

# %%
startup_df.drop(columns=["founded_at", "first_funding_at", "last_funding_at"], axis=1, inplace=True)

# %%
corr_matrix=startup_df.corr()
corr_matrix["labels"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
startup_df.to_csv("Resources/startup_data_cleaned.csv")

# %%
startup_df.describe()
# Out:
#            labels  age_first_funding_year  age_last_funding_year  \
# count  923.000000              923.000000             923.000000
# mean     0.646804                2.235630               3.931456
# std      0.478222                2.510449               2.967910
# min      0.000000               -9.046600              -9.046600
# 25%      0.000000                0.576700               1.669850
# 50%      1.000000                1.446600               3.528800
# 75%      1.000000                3.575350               5.560250
# max      1.000000               21.895900              21.895900
#
#        age_first_milestone_year  age_last_milestone_year  relationships  \
# count                771.000000               771.000000     923.000000
# mean                   3.055353                 4.754423       7.710726
# std                    2.977057                 3.212107       7.265776
# min                  -14.169900                -7.005500       0.000000
# ...

# %%
startup_df.iloc[:, 1:].hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'age_first_funding_year'}>,
#         <AxesSubplot:title={'center':'age_last_funding_year'}>,
#         <AxesSubplot:title={'center':'age_first_milestone_year'}>,
#         <AxesSubplot:title={'center':'age_last_milestone_year'}>,
#         <AxesSubplot:title={'center':'relationships'}>,
#         <AxesSubplot:title={'center':'funding_rounds'}>],
#        [<AxesSubplot:title={'center':'funding_total_usd'}>,
#         <AxesSubplot:title={'center':'milestones'}>,
#         <AxesSubplot:title={'center':'is_CA'}>,
#         <AxesSubplot:title={'center':'is_NY'}>,
#         <AxesSubplot:title={'center':'is_MA'}>,
#         <AxesSubplot:title={'center':'is_TX'}>],
#        [<AxesSubplot:title={'center':'is_otherstate'}>,
#         <AxesSubplot:title={'center':'is_software'}>,
#         <AxesSubplot:title={'center':'is_web'}>,
#         <AxesSubplot:title={'center':'is_mobile'}>,
#         <AxesSubplot:title={'center':'is_enterprise'}>,
# ...
