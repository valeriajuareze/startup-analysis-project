# %%
#Import dependency
import pandas as pd

# %%
#Export the database to a DataFrame
startup_df= pd.read_csv("startup_data.csv")
startup_df
# Out:
#     state_code  labels  founded_at  age_first_funding_year  \
# 0           CA       1        2007                  2.2493
# 1           CA       1        2000                  5.1260
# 2           CA       1        2009                  1.0329
# 3           CA       1        2002                  3.1315
# 4           CA       0        2010                  0.0000
# ..         ...     ...         ...                     ...
# 918         CA       1        2009                  0.5178
# 919         MA       0        1998                  7.2521
# 920         CA       0        1999                  8.4959
# 921         CA       1        2009                  0.7589
# 922         CA       1        2003                  3.1205
#
#      age_last_funding_year  age_first_milestone_year  age_last_milestone_year  \
# 0                   3.0027                    4.6685                   6.7041
# 1                   9.9973                    7.0055                   7.0055
# ...

# %%
#Change the N/A values to 999 
startup_df["age_first_milestone_year"] = startup_df["age_first_milestone_year"].fillna(value=999)
startup_df["age_last_milestone_year"] = startup_df["age_last_milestone_year"].fillna(value=999)
startup_df
# Out:
#     state_code  labels  founded_at  age_first_funding_year  \
# 0           CA       1        2007                  2.2493
# 1           CA       1        2000                  5.1260
# 2           CA       1        2009                  1.0329
# 3           CA       1        2002                  3.1315
# 4           CA       0        2010                  0.0000
# ..         ...     ...         ...                     ...
# 918         CA       1        2009                  0.5178
# 919         MA       0        1998                  7.2521
# 920         CA       0        1999                  8.4959
# 921         CA       1        2009                  0.7589
# 922         CA       1        2003                  3.1205
#
#      age_last_funding_year  age_first_milestone_year  age_last_milestone_year  \
# 0                   3.0027                    4.6685                   6.7041
# 1                   9.9973                    7.0055                   7.0055
# ...

# %%
#Export the DataFrame to a CSV file
startup_df.to_csv("startup_data.csv")
